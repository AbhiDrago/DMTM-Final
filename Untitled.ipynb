# %% [markdown]
# DMTM CS583 Research Project

# %%
# Importing required Libraries

import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv("obama.csv")
data
# Out:
#                                                   Tweet Class
# 0     Kirkpatrick, who wore a baseball cap embroider...     0
# 1     Question: If <e>Romney</e> and <e>Obama</e> ha...     2
# 2     #<e>obama</e> debates that Cracker Ass Cracker...     1
# 3     RT @davewiner Slate: Blame <e>Obama</e> for fo...     2
# 4     @Hollivan @hereistheanswer  Youre missing the ...     0
# ...                                                 ...   ...
# 7194   The Reason <e>Ann Romney</e> And <e>Michelle ...     0
# 7195   <e>Obama</e> Kenakan Cincin Syahadat Sejak SM...     0
# 7196   Bitches be like "Obama<3" bitches just want <...     0
# 7197   <e>president</e> Barack <e>Obama</e> and Repu...     2
# 7198   #ThatsSoRude you trying to get into Obama's f...     2
#
# [7199 rows x 2 columns]

# %%
mydata = data
type(mydata['Tweet'][9])
# Out:
# str

# %%
# Define a function to clean the text
def clean(text):
# Removes all special characters and numericals leaving the alphabets
    text = re.sub('[^A-Za-z]+', ' ', str(text))
    return text

# Cleaning the text in the review column
mydata['Cleaned Tweet'] = mydata['Tweet'].apply(clean)
mydata
# Out:
#                                                   Tweet Class  \
# 0     Kirkpatrick, who wore a baseball cap embroider...     0
# 1     Question: If <e>Romney</e> and <e>Obama</e> ha...     2
# 2     #<e>obama</e> debates that Cracker Ass Cracker...     1
# 3     RT @davewiner Slate: Blame <e>Obama</e> for fo...     2
# 4     @Hollivan @hereistheanswer  Youre missing the ...     0
# ...                                                 ...   ...
# 7194   The Reason <e>Ann Romney</e> And <e>Michelle ...     0
# 7195   <e>Obama</e> Kenakan Cincin Syahadat Sejak SM...     0
# 7196   Bitches be like "Obama<3" bitches just want <...     0
# 7197   <e>president</e> Barack <e>Obama</e> and Repu...     2
# 7198   #ThatsSoRude you trying to get into Obama's f...     2
#
#                                           Cleaned Tweet
# 0     Kirkpatrick who wore a baseball cap embroidere...
# 1     Question If e Romney e and e Obama e had a chi...
# ...

# %%
mydata = data.drop('Tweet', axis=1)
mydata
# Out:
#      Class                                      Cleaned Tweet
# 0        0  Kirkpatrick who wore a baseball cap embroidere...
# 1        2  Question If e Romney e and e Obama e had a chi...
# 2        1   e obama e debates that Cracker Ass Cracker to...
# 3        2  RT davewiner Slate Blame e Obama e for four de...
# 4        0   Hollivan hereistheanswer Youre missing the po...
# ...    ...                                                ...
# 7194     0   The Reason e Ann Romney e And e Michelle Obam...
# 7195     0   e Obama e Kenakan Cincin Syahadat Sejak SMA h...
# 7196     0   Bitches be like Obama bitches just want a foo...
# 7197     2   e president e Barack e Obama e and Republican...
# 7198     2   ThatsSoRude you trying to get into Obama s fa...
#
# [7199 rows x 2 columns]

# %%
stop = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "e", "s", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]
mydata['Cleaner'] = mydata['Cleaned Tweet'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
mydata
# Out:
#      Class                                      Cleaned Tweet  \
# 0        0  Kirkpatrick who wore a baseball cap embroidere...
# 1        2  Question If e Romney e and e Obama e had a chi...
# 2        1   e obama e debates that Cracker Ass Cracker to...
# 3        2  RT davewiner Slate Blame e Obama e for four de...
# 4        0   Hollivan hereistheanswer Youre missing the po...
# ...    ...                                                ...
# 7194     0   The Reason e Ann Romney e And e Michelle Obam...
# 7195     0   e Obama e Kenakan Cincin Syahadat Sejak SMA h...
# 7196     0   Bitches be like Obama bitches just want a foo...
# 7197     2   e president e Barack e Obama e and Republican...
# 7198     2   ThatsSoRude you trying to get into Obama s fa...
#
#                                                 Cleaner
# 0     Kirkpatrick wore baseball cap embroidered Bara...
# 1     Question If Romney Obama child punching contes...
# ...

# %%
mydata = mydata.drop('Cleaned Tweet', axis=1)
mydata
# Out:
#      Class                                            Cleaner
# 0        0  Kirkpatrick wore baseball cap embroidered Bara...
# 1        2  Question If Romney Obama child punching contes...
# 2        1  obama debates Cracker Ass Cracker tonight I tu...
# 3        2  RT davewiner Slate Blame Obama four deaths Lib...
# 4        0  Hollivan hereistheanswer Youre missing point I...
# ...    ...                                                ...
# 7194     0  The Reason Ann Romney And Michelle Obama Match...
# 7195     0  Obama Kenakan Cincin Syahadat Sejak SMA http c...
# 7196     0   Bitches like Obama bitches want food stamps lmao
# 7197     2  president Barack Obama Republican challenger M...
# 7198     2  ThatsSoRude trying get Obama face last night R...
#
# [7199 rows x 2 columns]

# %%
mydata.to_csv('file2.csv')
